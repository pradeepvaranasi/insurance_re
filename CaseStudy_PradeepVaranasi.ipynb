# %% [markdown]
# <a href="https://colab.research.google.com/github/pradeepvaranasi/insurance_re/blob/main/CaseStudy_PradeepVaranasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Business Objective

# %% [markdown]
# **Goal:** Increase Profitability by targeting Customer Retention.
#
# Cross-sell insurance (ppi) to the existing customer base who have a secured or unsecured type of loan, but no PPI product yet.

# %% [markdown]
# ####Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ####Importing Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_excel('drive/MyDrive/Mortgage_Insurance_Data.xls')

# %%
pd.set_option('display.max_columns', None)

# %%
data.head()
# Out:
#    Ref  Credit_Score Final_Grade  Term  Net_Advance   APR  Loan_Type  Mosaic  \
# 0    1           918           A    36       3000.0  14.4  UnSecured      46
# 1    3           903           A   120      21000.0   7.9  secured        16
# 2    4          1060           X    78       7200.0   7.9  secured        17
# 3    6           839           B    60       8000.0  16.9  UnSecured      47
# 4    7          1057           X    60       7650.0   7.4  UnSecured      55
#
#    Mosaic_Class  Time_at_Address Residential_Status Telephone_Indicator  \
# 0             8              132                  H                   Y
# 1             3              288                  H                   Y
# 2             3              276                  H                   Y
# 3             8               48                  R                   Y
# 4            10              156                  H                   Y
#
#    Number_of_Dependants Marital_Status Gender  Time_in_Employment  \
# ...
